# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidBarrera128/Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-utiliza-Lista-con-David-Barrera/blob/main/Act_9_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_utiliza_Lista_David_Barrera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### David Barrera NL = 8 Fecha 25 / 05 / 2026
# ### Act 9 Proyecto de simulación de inteligencia artificial  utiliza Lista,con if, else, elif  while tipo Menu
# # Clase : Ingeniero

# %%
# =====================================================================
#                 SISTEMA IA: Lista de Ingenieros
# =====================================================================

# Al inicio, la lista de conocimientos/registros empieza vacía
ingenieros = []

print("=====================================================")
print("🤖 ¡Bienvenido al simulador de IA para Ingenieros! 🤖")
print("=====================================================")

ejecutando = True

# Ciclo principal usando 'while'
while ejecutando:
    print("\n--- MENÚ DE CONTROL DE LA IA ---")
    print("1. Diagnosticar estado de un proyecto (Tomar decisiones)")
    print("2. Enseñar un nuevo concepto a la IA")
    print("3. Mostrar la base de conocimientos (Memoria de la IA)")
    print("4. Apagar la IA (Salir)")

    opcion = input("\nSelecciona una opción (1-4): ")

    # --- OPCIÓN 1: DIAGNÓSTICO (Uso de IF, ELIF, ELSE) ---
    if opcion == "1":
        print("\n--- MÓDULO DE DIAGNÓSTICO DE INGENIERÍA ---")
        print("¿Qué tipo de problema vas a analizar?")
        print("A) Estructural (Puentes/Edificios)")
        print("B) Eléctrico (Sistemas de energía)")

        tipo = input("Elige una opción (A o B): ").upper()

        if tipo == "A":
            grietas = input("¿El presupuesto está sobrepasado? (S/N): ").upper()
            if grietas == "S":
                print("-> IA: Alerta crítica. Recomiendo pausar la obra y recalcular costos.")
                ingenieros.append("Diagnóstico: Alerta de presupuesto en obra estructural.")
            else:
                print("-> IA: Todo en orden. Estructura y finanzas estables.")
                ingenieros.append("Diagnóstico: Proyecto estructural en condiciones óptimas.")

        elif tipo == "B":
            voltaje = input("¿El voltaje supera los 220V? (S/N): ").upper()
            if voltaje == "S":
                print("-> IA: Peligro de sobrecarga. Se sugiere instalar transformadores de seguridad.")
                ingenieros.append("Diagnóstico: Riesgo de sobrecarga eléctrica detectado.")
            else:
                print("-> IA: Flujo eléctrico normal y seguro.")
                ingenieros.append("Diagnóstico: Sistema eléctrico estable.")
        else:
            print("-> IA: Tipo de ingeniería no reconocido.")

    # --- OPCIÓN 2: AGREGAR DATOS A LA LISTA ---
    elif opcion == "2":
        print("\n--- MÓDULO DE APRENDIZAJE ---")
        nuevo_dato = input("Escribe una nueva regla o término de ingeniería para mi memoria: ")
        ingenieros.append(nuevo_dato)
        print("-> IA: ¡Entendido! He guardado ese conocimiento en mi lista.")

    # --- OPCIÓN 3: MOSTRAR LA LISTA USANDO WHILE (NO FOR) ---
    elif opcion == "3":
        print("\n--- MEMORIA ACTUAL DE LA IA ---")
        # Validamos si la lista está vacía con un if-else
        if len(ingenieros) == 0:
            print("La memoria está vacía. ¡Prueba las opciones 1 o 2 primero!")
        else:
            print("Datos registrados por la IA:")
            # Recorremos la lista con un ciclo while e índice
            contador = 0
            while contador < len(ingenieros):
                print(" Registro [" + str(contador + 1) + "]: " + ingenieros[contador])
                contador = contador + 1

    # --- OPCIÓN 4: SALIR ---
    elif opcion == "4":
        print("\nIA: Guardando datos y cerrando sistemas... ¡Hasta la próxima, Ingeniero!")
        ejecutando = False

    # --- VALIDACIÓN DE OPCIÓN INCORRECTA ---
    else:
        print("Opción no válida. Por favor, elige un número del 1 al 4.")

print("\n=====================================================")
print("          Programa finalizado con éxito.")
print("=====================================================")
print("programa realizado por David Barrera 1388")
# Out:
# ...
# 🤖 ¡Bienvenido al simulador de IA para Ingenieros! 🤖
# ...
#
# --- MENÚ DE CONTROL DE LA IA ---
# 1. Diagnosticar estado de un proyecto (Tomar decisiones)
# 2. Enseñar un nuevo concepto a la IA
# 3. Mostrar la base de conocimientos (Memoria de la IA)
# 4. Apagar la IA (Salir)
#
# Selecciona una opción (1-4): 1
#
# --- MÓDULO DE DIAGNÓSTICO DE INGENIERÍA ---
# ¿Qué tipo de problema vas a analizar?
# A) Estructural (Puentes/Edificios)
# B) Eléctrico (Sistemas de energía)
# Elige una opción (A o B): B
# ¿El voltaje supera los 220V? (S/N): S
# -> IA: Peligro de sobrecarga. Se sugiere instalar transformadores de seguridad.
#
# --- MENÚ DE CONTROL DE LA IA ---
# 1. Diagnosticar estado de un proyecto (Tomar decisiones)
# 2. Enseñar un nuevo concepto a la IA
# 3. Mostrar la base de conocimientos (Memoria de la IA)
# 4. Apagar la IA (Salir)
#
# Selecciona una opción (1-4): 2
#
# --- MÓDULO DE APRENDIZAJE ---
# Escribe una nueva regla o término de ingeniería para mi memoria: Seguridad electronica
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/DavidBarrera128/Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-utiliza-Lista-con-David-Barrera/refs/heads/main/Act%209%20Proyecto%20de%20simulaci%C3%B3n%20de%20inteligencia%20artificial%20%20utiliza%20Lista%20Infografia%20David%20Barrera.png)
